# %% [markdown]
# ### 🤖 Guía de Asistencia con IA: IA como Copiloto de Programación
#
# En esta notebook, utilizaremos la Inteligencia Artificial como copiloto de aprendizaje. Aquí tienes algunas sugerencias de cómo interactuar con un asistente de IA (como Gemini o ChatGPT):
#
# - **Explicación de código**: Si encuentras una función o línea que no comprendes, pregúntale a la IA: *'Explica qué hace esta función línea por línea en Python: [pega tu código]'*.
# - **Corrección de errores**: Si tienes un error al ejecutar, copia el error completo y pregúntale: *'¿Por qué este código genera este error y cómo lo soluciono? [pega tu código y error]'*.
# - **Optimización**: Pregunta: *'¿Cómo puedo escribir este código de forma más eficiente y limpia?'*.

# %%
# %pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in .\.venv\Lib\site-packages (3.11.1)
# Requirement already satisfied: seaborn in .\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in .\.venv\Lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in .\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in .\.venv\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Programa Ingenias+ en Data Science
#
# Como dijimos en clases anteriores, Python tiene implementadas muchas librerias para poder trabajar con datos. En la clase de hoy trabajaremos con una de ellas: `Pandas`.
#
# Antes de comenzar, vamos a hablar un poco de esta libreria.
#
# **Pandas** es una libreria que es una extensión de NumPy. Basicamente al utilizar `pandas`, utilizo `numpy` por debajo. Esta orientada a la manipulación y análisis de datos debido a que ofrece estructuras de datos y operaciones para manipular tablas numéricas y series temporales.
#
# La estructura principal de `pandas` es el `DataFrame` que es muy similar a una tabla. Así también, contiene otra estrucutra denominada `Serie`.
#
# Al ser de código abierto, `pandas` posee una documentación muy amplia que es **SIEMPRE RECOMENDABLE** consultar.
#
# - [Documentacion Pandas](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# ## Clase 5: Pandas

# %% [markdown]
# Pandas es una gran ayuda para manejar nuestros dataset. En la clase de hoy, veremos algunos conceptos basicos de pandas y como leer datasets.

# %%
#importa numpy
import numpy as np
#importa pandas
import pandas as pd

# %%
zanahoria = pd.Series(data = [1,2,3, 4, 6.7],
          index=['primero', 'segundo' ,'tercero', 'cuarto', 'quinto'])

# %%
type(zanahoria)
# Out:
# pandas.Series

# %%
zanahoria
# Out:
# primero    1.0
# segundo    2.0
# tercero    3.0
# cuarto     4.0
# quinto     6.7
# dtype: float64

# %%
zanahoria['tercero']
# Out:
# np.float64(3.0)

# %%
zanahoria
# Out:
# primero    1.0
# segundo    2.0
# tercero    3.0
# cuarto     4.0
# quinto     6.7
# dtype: float64

# %%
# Para si un objeto tiene una columna, lo que hacemos es guardar
# en una variable
espejo = pd.DataFrame(data = [1,"rosa",3, 4, 6.7],
          index=['primero', 'segundo' ,'tercero','cuarto',  'quinto'])
# Cuando creamos una variable tipo dataframe,
# debo tener la misma cantidad de datos que de indices

# %%
data = {'nombre': ['Ana', 'Juan'], 'edad': [20, 30]}
df = pd.DataFrame(data)
df
# Out:
#   nombre  edad
# 0    Ana    20
# 1   Juan    30

# %%
espejo.index
# Out:
# Index(['primero', 'segundo', 'tercero', 'cuarto', 'quinto'], dtype='str')

# %%
espejo.columns # metodo columna stop=1 una sola columna
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %% [markdown]
# Pandas nos facilita con varias funciones para leer archivos. Entre ellas podemos encontrar:
#
# - `.read_csv()`: lee archivos `csv` como DataFrame
# - `.read_json()`: lee archivos `json` como DataFrame
# - `.read_excel()`: leer archivos `excel` como DataFrame
#
# Para conocer más funciones que ayuden a leer archivos, consulta [acá](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)

# %% [markdown]
# Nosotras vamos a usar [`.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).

# %% [markdown]
# Los archivos `csv` son un tipo de documento en formato abierto sencillo para representar datos en forma de tabla, en las que las columnas se separan por comas (o punto y coma) y las filas por saltos de línea. Es uno de los formatos más utilizados en Data Science.

# %% [markdown]
# La sintaxis para poder leer un archivo csv es:
#
# `df = pd.read_csv('nombredelarchivo.csv', delimiter=',')`
#
# Aunque muchas veces se omite el `delimiter` si el archivo esta separado por comas.

# %% [markdown]
# Vamos a trabajar con el archivo `StudentsPerformance.csv`. Es usual descargar el archivo `csv` en la misma carpeta en la que trabajas con el jupyter notebook. De esta manera, no tendras que especificar el path a tu archivo.

# %% [markdown]
# 1) Lee el archivo csv `StudentsPerformace` usando `pandas`. Guardalo en una variable llamada `students`.

# %%
dfjuanma = pd.read_csv('StudentsPerformance.csv')

# %%
dfjuanma = pd.read_csv('StudentsPerformance.csv')

# %% [markdown]
# # Nueva sección

# %%
dfjuanma = pd.read_csv('StudentsPerformance.csv', delimiter=',')

# %%
dfjuanma
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 0             0  female        group B           bachelor's degree
# 1             1  female        group C                some college
# 2             2  female        group B             master's degree
# 3             3    male        group A          associate's degree
# 4             4    male        group C                some college
# ..          ...     ...            ...                         ...
# 995         995  female        group E             master's degree
# 996         996    male        group C                 high school
# 997         997  female        group C                 high school
# 998         998  female        group D                some college
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none         7.2             72
# 1        standard               completed         6.9             90
# 2        standard                    none         9.0             95
# 3    free/reduced                    none         4.7             57
# 4        standard                    none         7.6             78
# ..            ...                     ...         ...            ...
# 995      standard               completed         8.8             99
# 996  free/reduced                    none         6.2             55
# 997  free/reduced               completed         5.9             71
# 998      standard               completed         6.8             78
# 999  free/reduced                    none         7.7             86
#
#      writing score
# 0               74
# 1               88
# 2               93
# 3               44
# 4               75
# ..             ...
# 995             95
# 996             55
# 997             65
# 998             77
# 999             86
#
# [1000 rows x 9 columns]

# %%
# @title parental level of education

from matplotlib import pyplot as plt
import seaborn as sns
dfjuanma.groupby('parental level of education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dfjuanma.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
dfjuanma.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'race/ethnicity', 'parental level of education',
#        'lunch', 'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %% [markdown]
# 2) ¿Que tipo de estructura de datos contiene la variable `students`? _Hint_: Usa `type`

# %%
type(dfjuanma)
# Out:
# pandas.DataFrame

# %%
type(dfjuanma["math score"])
# Out:
# pandas.Series

# %% [markdown]
# 3) ¿Cuantas filas y columnas tiene `students`? Para contestar esta pregunta, pandas tiene la funcion `.shape()`. Su sintaxis es la siguiente: `df.shape()` (`df` debe ser reemplazado por el nombre de tu `DataFrame`).
#
#
# De ahora en más cuando nos refiramos a un tipo de sintaxis donde debe colocarse `nombre_del_data_frame.funcion()`, la mencionaremos como `.funcion()`.
#
# ¿Que devuelve esta funcion? ¿Cual crees que corresponde a las filas y cual a las columnas?

# %% [markdown]
# **Numero de filas**: ____

# %% [markdown]
# **Numero de columnas**: ____

# %%
dfjuanma.shape
# Out:
# (1000, 9)

# %% [markdown]
# 3) ¿Cual es el nombre de las columnas contenidas en `students`? Para esto, pandas tiene el atributo `.columns`.

# %%
dfjuanma.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'race/ethnicity', 'parental level of education',
#        'lunch', 'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %% [markdown]
# 4) Inspecciona las primeras 10 filas de `students` usando la función `.head()`. Dentro de esta función podemos colocar un numero. Este numero nos dira cuantas filas queremos observar.

# %%
dfjuanma.head()
# Out:
#    Unnamed: 0  gender race/ethnicity parental level of education  \
# 0           0  female        group B           bachelor's degree
# 1           1  female        group C                some college
# 2           2  female        group B             master's degree
# 3           3    male        group A          associate's degree
# 4           4    male        group C                some college
#
#           lunch test preparation course  math score  reading score  \
# 0      standard                    none         7.2             72
# 1      standard               completed         6.9             90
# 2      standard                    none         9.0             95
# 3  free/reduced                    none         4.7             57
# 4      standard                    none         7.6             78
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %% [markdown]
# 5) Ahora inspecciona las 10 ultimas usando `.tail()`. También podemos indicar el número de filas que queremos observar.

# %%
dfjuanma.tail(10)
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 990         990    male        group E                 high school
# 991         991  female        group B            some high school
# 992         992  female        group D          associate's degree
# 993         993  female        group D           bachelor's degree
# 994         994    male        group A                 high school
# 995         995  female        group E             master's degree
# 996         996    male        group C                 high school
# 997         997  female        group C                 high school
# 998         998  female        group D                some college
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 990  free/reduced               completed         8.6             81
# 991      standard               completed         6.5             82
# 992  free/reduced                    none         5.5             76
# 993  free/reduced                    none         6.2             72
# 994      standard                    none         6.3             63
# 995      standard               completed         8.8             99
# 996  free/reduced                    none         6.2             55
# 997  free/reduced               completed         5.9             71
# 998      standard               completed         6.8             78
# 999  free/reduced                    none         7.7             86
#
#      writing score
# 990             75
# 991             78
# 992             76
# 993             74
# 994             62
# 995             95
# 996             55
# 997             65
# 998             77
# 999             86

# %% [markdown]
# 6) ¿Que tipos de datos contiene cada una de las columnas de `students`? Para esto, utiliza el atributo `.dtypes`.

# %%
dfjuanma.dtypes
# Out:
# Unnamed: 0                       int64
# gender                             str
# race/ethnicity                     str
# parental level of education        str
# lunch                              str
# test preparation course            str
# math score                     float64
# reading score                    int64
# writing score                    int64
# dtype: object

# %% [markdown]
# 7) ¿Como accedemos a una fila o a una columa de un DataFrame?

# %% [markdown]
# Una de las maneras de acceder a una columna es especificando el nombre de la misma. Por ejemplo, `df['nombre_columna']`.

# %% [markdown]
# - Accede a la columna `gender` de `students`.

# %%
dfjuanma['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %%
dfjuanma.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %% [markdown]
# - Accede ahora a la columna `lunch`.

# %%
dfjuanma['lunch']
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: str

# %%
df.lunch
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: str

# %%
dfjuanma["lunch"].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %% [markdown]
# Otra manera de acceder es usando dos funciones `.loc[]` y `.iloc[]`.

# %% [markdown]
# - `iloc[1:m, 1:n]`: Se usa para seleccionar filas basadas en su posición de 1 a m filas y de 1 a n columnas.

# %%
#seleccionar las dos primeras filas
dfjuanma.iloc[:2, :3]
# Out:
#    Unnamed: 0  gender race/ethnicity
# 0           0  female        group B
# 1           1  female        group C

# %%
#o tambien se usa
dfjuanma.iloc[:5,]
# Out:
#    Unnamed: 0  gender race/ethnicity parental level of education  \
# 0           0  female        group B           bachelor's degree
# 1           1  female        group C                some college
# 2           2  female        group B             master's degree
# 3           3    male        group A          associate's degree
# 4           4    male        group C                some college
#
#           lunch test preparation course  math score  reading score  \
# 0      standard                    none         7.2             72
# 1      standard               completed         6.9             90
# 2      standard                    none         9.0             95
# 3  free/reduced                    none         4.7             57
# 4      standard                    none         7.6             78
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
dfjuanma.iloc[1,3]
# Out:
# 'some college'

# %%
#Selecciona los datos entre la decima y vigesima fila.
dfjuanma.iloc[10:21]
# Out:
#     Unnamed: 0  gender race/ethnicity parental level of education  \
# 10          10    male        group C          associate's degree
# 11          11    male        group D          associate's degree
# 12          12  female        group B                 high school
# 13          13    male        group A                some college
# 14          14  female        group A             master's degree
# 15          15  female        group C            some high school
# 16          16    male        group C                 high school
# 17          17  female        group B            some high school
# 18          18    male        group C             master's degree
# 19          19  female        group C          associate's degree
# 20          20    male        group D                 high school
#
#            lunch test preparation course  math score  reading score  \
# 10      standard                    none         5.8             54
# 11      standard                    none         4.0             52
# 12      standard                    none         6.5             81
# 13      standard               completed         7.8             72
# 14      standard                    none         5.0             53
# 15      standard                    none         6.9             75
# 16      standard                    none         8.8             89
# 17  free/reduced                    none         1.8             32
# 18  free/reduced               completed         4.6             42
# 19  free/reduced                    none         5.4             58
# 20      standard                    none         6.6             69
#
#     writing score
# 10             52
# 11             43
# 12             73
# 13             70
# 14             58
# 15             78
# 16             86
# 17             28
# 18             46
# 19             61
# 20             63

# %%
#Selecciona las dos primeras columnas
dfjuanma.iloc[:, :2]
# Out:
#      Unnamed: 0  gender
# 0             0  female
# 1             1  female
# 2             2  female
# 3             3    male
# 4             4    male
# ..          ...     ...
# 995         995  female
# 996         996    male
# 997         997  female
# 998         998  female
# 999         999  female
#
# [1000 rows x 2 columns]

# %% [markdown]
# - `.loc[[nombre_fila], [nombre_columna]]`. Se usa para seleccionar filas o columnas basadas en su nombre

# %%
#Selecciona la fila por nombre 1, o sea con indice igual a 1
dfjuanma.loc[1] #para el nombre de la fila sigue usando indice, la columna ahi si string
# Out:
# Unnamed: 0                                1
# gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course           completed
# math score                              6.9
# reading score                            90
# writing score                            88
# Name: 1, dtype: object

# %%
#Corre el codigo y observa que devuelve
dfjuanma.loc[[1,20,3,4,5],['gender','lunch']]
# Out:
#     gender         lunch
# 1   female      standard
# 20    male      standard
# 3     male  free/reduced
# 4     male      standard
# 5   female      standard

# %%
#Selecciona las filas con indices 3, 10, 30, 43, 43 y columnas reading score y writing score
dfjuanma.loc[[3, 10, 30, 43, 43], ['reading score', 'writing score']]
# Out:
#     reading score  writing score
# 3              57             44
# 10             54             52
# 30             74             74
# 43             65             66
# 43             65             66

# %%
df2 = pd.DataFrame(data = ['perro', 'gato', 'flor'], index = ['str1', 'str2', 'st32'], columns=['titulo'])

# %%
df2
# Out:
#      titulo
# str1  perro
# str2   gato
# st32   flor

# %%
df2.loc['str2'] # lo toma como String, porque lo force antes de que sea un string y no un numero al indice
# Out:
# titulo    gato
# Name: str2, dtype: str

# %%
df2.iloc[1]
# Out:
# titulo    gato
# Name: str2, dtype: str

# %% [markdown]
# 8) A veces queremos seleccionar filas que cumplan con ciertas condiciones, donde el valor de una columna en esa fila sea igual, mayor o menor que un valor.
#
# Para esto tenemos que usar una sintaxis especial. Vamos a construirla de a poco. Imaginemos que tenemos un DataFrame `df` con las columnas `col1`, `col2` y `col3`. Queremos seleccionar solo aquellas filas donde `col1` sea mayor a 10.
#
# Para eso diremos que queremos
#
# df['col1'] > 10 (La columna col1 debe ser mayor a 10).
# Ahora si corremos este codigo, veremos que devuelve valores booleanos. O sea devolvera False para aquellos valores que sean menores o iguales a 10 y True para los que sean mayores a 10.
#
# O sea que tenemos que agregar algo mas para poder seleccionar las columnas. Esta lista de valores booleanos se llama mascara booleana.
#
# ¿Que significa? Que si yo le paso estos valores a pandas, pandas interpretara que debe conservar aquellos valores donde tiene True y descartar donde tiene False.
#
# Por eso, para filtrar filas en base a estas condiciones escribimos:
#
# df[df['col1] > 10].
#
# Esto significa primero fijate en que filas de `df`, la columna `col1` es mayor a 10. Luego, selecciona solo aquellas filas donde esta condicion sea `True`.

# %%
ejemplo = pd.DataFrame(data = [100,2,3, 4, 15,34],
          index=[1,2,3,4,5,6], columns=["col1"])

# %%
ejemplo
# Out:
#    col1
# 1   100
# 2     2
# 3     3
# 4     4
# 5    15
# 6    34

# %%
ejemplo['col1']>10
# Out:
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# Name: col1, dtype: bool

# %%
ejemplo[ejemplo['col1']>10]
# Out:
#    col1
# 1   100
# 5    15
# 6    34

# %%
#Selecciona solo las filas donde math score sea mayor a 70
dfjuanma[dfjuanma['math score']>7.0]
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 0             0  female        group B           bachelor's degree
# 2             2  female        group B             master's degree
# 4             4    male        group C                some college
# 5             5  female        group B          associate's degree
# 6             6  female        group B                some college
# ..          ...     ...            ...                         ...
# 984         984  female        group C            some high school
# 987         987    male        group E            some high school
# 990         990    male        group E                 high school
# 995         995  female        group E             master's degree
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none         7.2             72
# 2        standard                    none         9.0             95
# 4        standard                    none         7.6             78
# 5        standard                    none         7.1             83
# 6        standard               completed         8.8             95
# ..            ...                     ...         ...            ...
# 984      standard                    none         7.4             75
# 987      standard               completed         8.1             75
# 990  free/reduced               completed         8.6             81
# 995      standard               completed         8.8             99
# 999  free/reduced                    none         7.7             86
#
#      writing score
# 0               74
# 2               93
# 4               75
# 5               78
# 6               92
# ..             ...
# 984             82
# 987             76
# 990             75
# 995             95
# 999             86
#
# [391 rows x 9 columns]

# %%
#Selecciona solo las filas donde reading score sea menor a 60
dfjuanma[dfjuanma['reading score']<60]
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 3             3    male        group A          associate's degree
# 7             7    male        group B                some college
# 10           10    male        group C          associate's degree
# 11           11    male        group D          associate's degree
# 14           14  female        group A             master's degree
# ..          ...     ...            ...                         ...
# 980         980  female        group B                 high school
# 985         985    male        group A                 high school
# 986         986  female        group C          associate's degree
# 988         988  female        group A            some high school
# 996         996    male        group C                 high school
#
#             lunch test preparation course  math score  reading score  \
# 3    free/reduced                    none         4.7             57
# 7    free/reduced                    none         4.0             43
# 10       standard                    none         5.8             54
# 11       standard                    none         4.0             52
# 14       standard                    none         5.0             53
# ..            ...                     ...         ...            ...
# 980  free/reduced                    none         0.8             24
# 985      standard                    none         5.7             51
# 986      standard                    none         4.0             59
# 988  free/reduced                    none         4.4             45
# 996  free/reduced                    none         6.2             55
#
#      writing score
# 3               44
# 7               39
# 10              52
# 11              43
# 14              58
# ..             ...
# 980             23
# 985             54
# 986             51
# 988             45
# 996             55
#
# [254 rows x 9 columns]

# %%
#Selecciona solo las filas donde gender sea igual a female
dfjuanma[dfjuanma['gender']=='female']
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 0             0  female        group B           bachelor's degree
# 1             1  female        group C                some college
# 2             2  female        group B             master's degree
# 5             5  female        group B          associate's degree
# 6             6  female        group B                some college
# ..          ...     ...            ...                         ...
# 993         993  female        group D           bachelor's degree
# 995         995  female        group E             master's degree
# 997         997  female        group C                 high school
# 998         998  female        group D                some college
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none         7.2             72
# 1        standard               completed         6.9             90
# 2        standard                    none         9.0             95
# 5        standard                    none         7.1             83
# 6        standard               completed         8.8             95
# ..            ...                     ...         ...            ...
# 993  free/reduced                    none         6.2             72
# 995      standard               completed         8.8             99
# 997  free/reduced               completed         5.9             71
# 998      standard               completed         6.8             78
# 999  free/reduced                    none         7.7             86
#
#      writing score
# 0               74
# 1               88
# 2               93
# 5               78
# 6               92
# ..             ...
# 993             74
# 995             95
# 997             65
# 998             77
# 999             86
#
# [518 rows x 9 columns]

# %%
#Selecciona solo aquellas filas donde lunch sea distinto a standardisnull
dfjuanma[(dfjuanma['lunch']!='standard') & dfjuanma['lunch'].notnull()]
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 3             3    male        group A          associate's degree
# 7             7    male        group B                some college
# 8             8    male        group D                 high school
# 9             9  female        group B                 high school
# 17           17  female        group B            some high school
# ..          ...     ...            ...                         ...
# 992         992  female        group D          associate's degree
# 993         993  female        group D           bachelor's degree
# 996         996    male        group C                 high school
# 997         997  female        group C                 high school
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 3    free/reduced                    none         4.7             57
# 7    free/reduced                    none         4.0             43
# 8    free/reduced               completed         6.4             64
# 9    free/reduced                    none         3.8             60
# 17   free/reduced                    none         1.8             32
# ..            ...                     ...         ...            ...
# 992  free/reduced                    none         5.5             76
# 993  free/reduced                    none         6.2             72
# 996  free/reduced                    none         6.2             55
# 997  free/reduced               completed         5.9             71
# 999  free/reduced                    none         7.7             86
#
#      writing score
# 3               44
# 7               39
# 8               67
# 9               50
# 17              28
# ..             ...
# 992             76
# 993             74
# 996             55
# 997             65
# 999             86
#
# [355 rows x 9 columns]

# %%
#Muestra los valores de writing score para aquellos estudiantes que tengan reading score mayor a math score
dfjuanma.loc[dfjuanma['reading score'] > dfjuanma['math score'], 'writing score']
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %%
#Selecciona aquellos estudiantes que posean reading and writing score mayor a 70
dfjuanma[(dfjuanma['reading score'] > 70) & (dfjuanma['writing score'] > 70)]
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 0             0  female        group B           bachelor's degree
# 1             1  female        group C                some college
# 2             2  female        group B             master's degree
# 4             4    male        group C                some college
# 5             5  female        group B          associate's degree
# ..          ...     ...            ...                         ...
# 992         992  female        group D          associate's degree
# 993         993  female        group D           bachelor's degree
# 995         995  female        group E             master's degree
# 998         998  female        group D                some college
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none         7.2             72
# 1        standard               completed         6.9             90
# 2        standard                    none         9.0             95
# 4        standard                    none         7.6             78
# 5        standard                    none         7.1             83
# ..            ...                     ...         ...            ...
# 992  free/reduced                    none         5.5             76
# 993  free/reduced                    none         6.2             72
# 995      standard               completed         8.8             99
# 998      standard               completed         6.8             78
# 999  free/reduced                    none         7.7             86
#
#      writing score
# 0               74
# 1               88
# 2               93
# 4               75
# 5               78
# ..             ...
# 992             76
# 993             74
# 995             95
# 998             77
# 999             86
#
# [419 rows x 9 columns]

# %% [markdown]
# 9) Los valores faltantes son un problema muy grande a la hora de visualizar y limpiar datos así como también a la hora de entrenar un modelo. Uno de los pasos obligados de cualquier exploración de datos es evaluar la presencia de estos valores.
#
# Como manejar estos datos faltantes es un gran desafio. La mayoría de las veces no queremos eliminar esos valores porque significaría perder información valiosa en otros features. En la proxima clase veremos como podemos manejarlos.
#
# Los valores faltantes estan codificados normalemente como `NaN`. Esto no es un string, sino que es un valor especial de `NumPy` que es tratado como un flotante.
#
# Para chequear si tenemos valores faltantes podemos usar la función `.isnull()`. Esto nos devuelve una nueva DataFrame en la cual tendremos el valor False si no es faltante y True si ese valor es faltante.

# %%
#Usa .isnull() para ver que ocurre
dfjuanma.isnull()
# Out:
#      Unnamed: 0  gender  race/ethnicity  parental level of education  lunch  \
# 0         False   False           False                        False  False
# 1         False   False           False                        False  False
# 2         False   False           False                        False  False
# 3         False   False           False                        False  False
# 4         False   False           False                        False  False
# ..          ...     ...             ...                          ...    ...
# 995       False   False           False                        False  False
# 996       False   False           False                        False  False
# 997       False   False           False                        False  False
# 998       False   False           False                        False  False
# 999       False   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# 1                      False       False          False          False
# 2                      False       False          False          False
# 3                      False       False          False          False
# 4                      False       False          False          False
# ..                       ...         ...            ...            ...
# 995                    False       False          False          False
# 996                    False       False          False          False
# 997                    False       False          False          False
# 998                    False       False          False          False
# 999                    False       False          False          False
#
# [1000 rows x 9 columns]

# %% [markdown]
# Podemos sin embargo combinar esta función con otras para poder obtener el numero total de datos faltantes. Por ejemplo, podemos usar `.isnull().sum()`.

# %%
#Prueba usar .isnull().sum() sobre tu dataframe para ver que devuelve
dfjuanma.isnull().sum()
# Out:
# Unnamed: 0                     0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# ¿Hay valores faltantes en alguna de las columnas de `students`? ____

# %% [markdown]
# 10) Si la cantidad de valores faltantes es poca, podemos entonces deshacernos de ellas. Para esto pandas ofrece la función [`.dropna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html). Esta función hara que se eliminen las filas donde hay valores faltantes. Si no le pasamos ningun parametro extra, eliminara todas las filas con valores faltantes. Sin embargo, podes chequear en la documentación como eliminar solo algunas de las filas.

# %%
#Elimina todas las filas que tengan valores faltantes. No te olvides de poner inplace=True dentro de la función.
dfjuanma.dropna(inplace=True)

# %% [markdown]
# 12) Una manera de ver facilmente algunos detalles estadisticos de cada columna de un DataFrame es usando la fución `.describe()`.

# %%
#Usa la funcion .describe() sobre students y describe que informacion estadistica proporciona
dfjuanma.describe()
# Out:
#         Unnamed: 0   math score  reading score  writing score
# count  1000.000000  1000.000000    1000.000000    1000.000000
# mean    499.500000     6.608900      69.169000      68.054000
# std     288.819436     1.516308      14.600192      15.195657
# min       0.000000     0.000000      17.000000      10.000000
# 25%     249.750000     5.700000      59.000000      57.750000
# 50%     499.500000     6.600000      70.000000      69.000000
# 75%     749.250000     7.700000      79.000000      79.000000
# max     999.000000    10.000000     100.000000     100.000000

# %% [markdown]
# count: Cantidad de valores no nulos presentes en la columna (en tu caso, 1000 registros).
#
# mean: El promedio (media aritmética) de los datos.
#
# std: La desviación estándar, que mide qué tan dispersos están los datos con respecto al promedio.
#
# min: El valor mínimo registrado en la columna.
#
# 25%: El primer cuartil (Q1); el 25% de los datos es menor o igual a este valor.
#
# 50%: La mediana (Q2); el punto medio exacto donde el 50% de los datos cae por debajo y el 50% por encima.
#
# 75%: El tercer cuartil (Q3); el 75% de los datos es menor o igual a este valor.
#
# max: El valor máximo registrado en la columna.

# %% [markdown]
# Tambien es posible visualizar, por ejemplo, el promedio de una columna. Para esto pandas usa la función de numpy, pero provee la misma sintaxis que las demás funciones. Por ejemplo, si queremos calcular el promedio de la columna `col1` del DataFrame `df` usamos `df['col1'].mean()`.

# %%
#Calcula el promedio de la columna math score de students
dfjuanma['math score'].mean()
# Out:
# np.float64(6.608899999999999)

# %% [markdown]
# También podemos usar funciones como `.min()`, `.max()`, `.median()`, `.std()`.

# %%
#Calcula el minimo y maximo valor, la mediana y el desvio estandard en la columna math score de students
dfjuanma['math score'].min()
# Out:
# np.float64(0.0)

# %%
dfjuanma['math score'].max()
# Out:
# np.float64(10.0)

# %%
dfjuanma['math score'].median()
# Out:
# np.float64(6.6)

# %%
dfjuanma['math score'].std()
# Out:
# np.float64(1.5163080096009451)

# %% [markdown]
# 14) [Investiga](https://pandas.pydata.org/pandas-docs/stable/index.html) y trata de aplicar las siguientes funciones de `pandas`:

# %% [markdown]
# ```
#
# - `.index`

# %% [markdown]
# Accede a los índices (las etiquetas de las filas) del DataFrame.

# %%
dfjuanma.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# - `.drop()`

# %% [markdown]
# Elimina filas o columnas.

# %%
# Elimina la columna 'Unnamed: 0' (axis=1 indica columnas)
dfjuanma.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dfjuanma.shape
# Out:
# (1000, 8)

# %% [markdown]
# - `.groupby()`

# %% [markdown]
# Agrupa los datos por una o más columnas para aplicar cálculos agregados.

# %%
# Agrupa por género y calcula el promedio del resto de las notas
dfjuanma.groupby('gender').mean(numeric_only=True)
# Out:
#         math score  reading score  writing score
# gender
# female    6.363320      72.608108      72.467181
# male      6.872822      65.473029      63.311203

# %% [markdown]
# - `.fillna()`

# %% [markdown]
#  Reemplaza los nulos en la columna 'math score' con un 0
# Rellena los valores faltantes (NaN) con un valor específico en lugar de borrarlos.

# %%
dfjuanma['math score'] = dfjuanma['math score'].fillna(0)

# %%
# Opción usando .fillna con un diccionario:
dfjuanma.fillna({'math score': 0}, inplace=True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none         7.2             72             74
# 1                 completed         6.9             90             88
# 2                      none         9.0             95             93
# 3                      none         4.7             57             44
# 4                      none         7.6             78             75
# ..                      ...         ...            ...            ...
# 995               completed         8.8             99             95
# 996                    none         6.2             55             55
# 997               completed         5.9             71             65
# 998               completed         6.8             78             77
# 999                    none         7.7             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# - `.rename()`

# %% [markdown]
# Cambia los nombres de columnas o filas.

# %%
# Renombra la columna 'gender' a 'genero'
dfjuanma.rename(columns={'gender': 'genero'}, inplace=True)

# %%
dfjuanma.columns
# Out:
# Index(['genero', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %% [markdown]
# - `.astype()`

# %% [markdown]
# Cambia el tipo de dato de una columna (por ejemplo, de texto a número o entero).

# %%
# Convierte la columna 'math score' a un número entero
dfjuanma['math score'] = dfjuanma['math score'].astype(int)

# %%
dfjuanma['math score']
# Out:
# 0      7
# 1      6
# 2      9
# 3      4
# 4      7
#       ..
# 995    8
# 996    6
# 997    5
# 998    6
# 999    7
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# - `.unique()`

# %% [markdown]
# Devuelve un arreglo con los valores únicos (sin repetir) de una columna.

# %%
# Muestra las opciones distintas que existen para la columna 'lunch'
dfjuanma['lunch'].unique()
# Out:
# <StringArray>
# ['standard', 'free/reduced']
# Length: 2, dtype: str

# %% [markdown]
# - `.value_counts()`

# %% [markdown]
# Cuenta cuántas veces aparece cada valor único en una columna.

# %%
# Cuenta cuántos estudiantes hay por cada grupo étnico
dfjuanma['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %% [markdown]
# - `.count()`

# %% [markdown]
# Cuenta la cantidad de valores no nulos en cada columna o fila.

# %%
# Devuelve la cantidad de registros válidos por columna
dfjuanma.count()
# Out:
# genero                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %% [markdown]
# - `.reset_index()`

# %% [markdown]
# Reinicia los índices del DataFrame a su valor por defecto (0, 1, 2, ...), muy útil después de agrupar o filtrar datos.

# %%
# Reinicia el índice convirtiendo el anterior en una columna normal
dfjuanma.reset_index(inplace=True)

# %%
dfjuanma["lunch"] != "standard"
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997     True
# 998    False
# 999     True
# Name: lunch, Length: 1000, dtype: bool

# %%
dfjuanma[dfjuanma["lunch"] != "standard"]
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 3             3    male        group A          associate's degree
# 7             7    male        group B                some college
# 8             8    male        group D                 high school
# 9             9  female        group B                 high school
# 17           17  female        group B            some high school
# ..          ...     ...            ...                         ...
# 992         992  female        group D          associate's degree
# 993         993  female        group D           bachelor's degree
# 996         996    male        group C                 high school
# 997         997  female        group C                 high school
# 999         999  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 3    free/reduced                    none         4.7             57
# 7    free/reduced                    none         4.0             43
# 8    free/reduced               completed         6.4             64
# 9    free/reduced                    none         3.8             60
# 17   free/reduced                    none         1.8             32
# ..            ...                     ...         ...            ...
# 992  free/reduced                    none         5.5             76
# 993  free/reduced                    none         6.2             72
# 996  free/reduced                    none         6.2             55
# 997  free/reduced               completed         5.9             71
# 999  free/reduced                    none         7.7             86
#
#      writing score
# 3               44
# 7               39
# 8               67
# 9               50
# 17              28
# ..             ...
# 992             76
# 993             74
# 996             55
# 997             65
# 999             86
#
# [355 rows x 9 columns]

# %%
dfjuanma['math score'] = dfjuanma['math score'].replace(7.2, np.nan)

# %%
dfjuanma.isnull().sum()
# Out:
# Unnamed: 0                      0
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     18
# reading score                   0
# writing score                   0
# dtype: int64

# %%
pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (from missingno) (2.5.2)
# Requirement already satisfied: matplotlib in .\.venv\Lib\site-packages (from missingno) (3.11.1)
# Collecting scipy (from missingno)
#   Using cached scipy-1.18.1-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: seaborn in .\.venv\Lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\.venv\Lib\site-packages (from matplotlib->missingno) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib->missingno) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib->missingno) (26.3)
# Requirement already satisfied: pillow>=9 in .\.venv\Lib\site-packages (from matplotlib->missingno) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib->missingno) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in .\.venv\Lib\site-packages (from seaborn->missingno) (3.0.5)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=1.2->seaborn->missingno) (2026.3)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Using cached scipy-1.18.1-cp314-cp314-win_amd64.whl (37.4 MB)
# Installing collected packages: scipy, missingno
#
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 2/2 [missingno]
#
# Successfully installed missingno-0.5.2 scipy-1.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
msno.bar(dfjuanma)
# Out:
# <Axes: >
